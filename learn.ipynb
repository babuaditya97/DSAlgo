# %%
"""The LinkedList code from before is provided below.
Add three functions to the LinkedList.
"get_position" returns the element at a certain position.
The "insert" function will add an element to a particular
spot in the list.
"delete" will delete the first element with that
particular value.
Then, use "Test Run" and "Submit" to run the test cases
at the bottom."""

class Element(object):
    def __init__(self, value):
        self.value = value
        self.next = None
        
class LinkedList(object):
    def __init__(self, head=None):
        self.head = head
        
    def append(self, new_element):
        current = self.head
        if self.head:
            while current.next:
                current = current.next
            current.next = new_element
        else:
            self.head = new_element
            
    def get_position(self, position):
        """Get an element from a particular position.
        Assume the first position is "1".
        Return "None" if position is not in the list."""
        current = self.head
        pos =1
        while current is not None:
            if pos == position:
                return current
            current = current.next
            pos = pos+1
        return None
    
    def insert(self, new_element, position):
        """Insert a new node at the given position.
        Assume the first position is "1".
        Inserting at position 3 means between
        the 2nd and 3rd elements."""

        if position == 1:
            new_element.next = self.head
            self.head = new_element
        else:
            current= self.head
            pos = 1
            while current.next:
                if pos == position-1:
                    new_element.next = current.next
                    current.next = new_element
                    print('b')
                    break
                current = current.next
                pos+=1
            else:
                if pos == position - 1:  # Reached the end of the list
                    current.next = new_element
    
    def delete(self, value):
        """Delete the first node with a given value."""
        current = self.head
        while current:
            prev = current
            current = current.next
            if current.value == value:
                prev.next = current.next
            current = current.next
# Test cases
# Set up some Elements
e1 = Element(1)
e2 = Element(2)
e3 = Element(67)
e4 = Element(4)

# %%
def print_ll(ll):
    h = ll.head
    while h:
        print(h.value, end='-->')
        h = h.next

# %%
ll = LinkedList()
print_ll(ll)
# Start setting up a LinkedList
ll = LinkedList()
ll.append(e1)
ll.append(e2)
ll.append(e3)
ll.append(e4)

# %%
print_ll(ll)
# Out:
# 1-->2-->67-->4-->

# %%
# Test insert
ll.insert(e4,3)
# Out:
# b

# %%
# Should print 4 now
print(ll.get_position(477).value)
# Out:
# 4

# %%
print_ll(ll)
# Out:
# 1-->2-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->67-->4-->6 ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[175], line 1
# ----> 1 print_ll(ll)
#
# Cell In[170], line 4, in print_ll(ll)
#       2 h = ll.head
#       3 while h:
# ----> 4     print(h.value, end='-->')
#       5     h = h.next
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/iostream.py:597, in OutStream.write(self, string)
#     595     raise ValueError(msg)
#     596 else:
# --> 597     is_child = not self._is_master_process()
#     598     # only touch the buffer in the IO thread to avoid races
#     599     with self._buffer_lock:
#
# File ~/.local/lib/python3.10/site-packages/ipykernel/iostream.py:468, in OutStream._is_master_process(self)
#     467 def _is_master_process(self):
# --> 468     return os.getpid() == self._master_pid
#
# KeyboardInterrupt:

# %%
# Out:
# 4

# %%
# Test delete
ll.delete(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[164], line 2
#       1 # Test delete
# ----> 2 ll.delete(1)
#
# Cell In[159], line 68, in LinkedList.delete(self, value)
#      66 prev = current
#      67 current = current.next
# ---> 68 if current.value == value:
#      69     prev.next = current.next
#      70 current = current.next
#
# KeyboardInterrupt:
